# %%
import json
import pandas as pd
import unicodedata
import re
from fuzzywuzzy import fuzz

COMP_MAP = {r.composerID: r.composerName 
            for i, r in pd.read_table('data/interim/composer_key.txt', sep='\t').iterrows()}

ARTIST_NULLKEYS = [
    'mbzid', 'country', 'gender', 'sortname', 
    'area_name', 'beginarea_name', 'endarea_name', 'area_id', 'beginarea_id', 'endarea_id',
    'lifespan_begin', 'lifespan_end', 'lifespan_ended'
]


def normalize(string):
    return str(unicodedata.normalize('NFKD', string))


def flatten_artist(artist):
    final = {k: None for k in ARTIST_NULLKEYS}
    final['n_aliases'] = 0
    final['n_tags'] = 0
    final['disambig_composer'] = False
    final['tag_composer'] = False

    # basics
    final['mbzid'] = artist['id']
    final['country'] = artist.get('country')
    final['gender'] = artist.get('gender')
    final['sortname'] = artist.get('sort-name')

    if artist.get('area'):
        final['area_name'] = artist.get('area').get('name')
        final['area_id'] = artist.get('area').get('id')

    if artist.get('begin-area'):
        final['beginarea_name'] = artist.get('begin-area').get('name')
        final['beginarea_id'] = artist.get('begin-area').get('id')
    
    if artist.get('end-area'):
        final['endarea_name'] = artist.get('end-area').get('name')
        final['endarea_id'] = artist.get('end-area').get('id')

    ls = artist.get('life-span')
    if ls:
        final['lifespan_begin'] = ls.get('begin')
        final['lifespan_end'] = ls.get('end')
        final['lifespan_ended'] = ls.get('ended')

    if artist.get('aliases'):
        final['n_aliases'] = len(artist['aliases'])

    tags = artist.get('tags')
    if tags:
        final['n_tags'] = len(tags)
        final['tag_composer'] = any([t['name'] == 'composer' for t in tags])

    disambig = artist.get('disambiguation')
    if disambig:
        final['disambig_composer'] = 'composer' in disambig

    return final


def first_pass(data):
    final = []
    for i, d in enumerate(data):
        # skip if nothing found by mbz
        if d is None:
            continue

        search = d.get('search')
        cleanname = search.get('name').replace('  ', ' ').replace(' sir ', ' ').replace(',', '').lower()
        cleanname = normalize(cleanname)
        artists = d.get('artists')

        for a in artists:
            
            # cut based off of mbz search 'score'
            if int(a['score']) < 95:
                continue
            
            # cut based off of fuzzy match score of names
            foundname = normalize(a['sort-name'].replace(', ', ' ').lower())
            foundname = re.sub(pattern='[^A-Za-z ]', repl='', string=foundname)
            cleanname = re.sub(pattern='[^A-Za-z ]', repl='', string=cleanname)
            
            tsr_score = fuzz.token_sort_ratio(cleanname, foundname)
            pr_score = fuzz.partial_ratio(cleanname, foundname)
            avg_score = (tsr_score + pr_score) / 2
            
            if avg_score < 80 or tsr_score < 70 or pr_score < 70:
                continue

            # save
            this_meta = {'index': i, 
                         'searchname': search.get('name'), 
                         'composerid': search.get('id'), 
                         'foundname': foundname, 'cleanname': cleanname,
                         'tsr_score': tsr_score, 'pr_score': pr_score, 
                         'avg_score': avg_score}
            this_match = flatten_artist(a)
            this_match.update(this_meta)

            final += [this_match]

    return pd.DataFrame(final)


def choose_best_match(data):
    # if single word name, this is hopeless
    if len(COMP_MAP[data.composerid.iloc[0]].split(',  ')) == 1:
        return None
    
    # filter by tagged composer
    n_tag_composer = sum(data.tag_composer)
    if n_tag_composer == 1:
        return data.loc[data.tag_composer==True, :]
    elif n_tag_composer > 1:
        data = data.loc[data.tag_composer==True, :].copy()
       
    # filter by disambig composer
    n_disambig_composer = sum(data.disambig_composer)
    if n_disambig_composer == 1:
        return data.loc[data.disambig_composer==True, :]
    elif n_disambig_composer > 1:
        data = data.loc[data.disambig_composer==True, :].copy()
    
    # take most aliases
    max_aliases = max(data.n_aliases)
    n_w_max_aliases = data.loc[data.n_aliases == max_aliases, :].shape[0]
    if max_aliases > 0 and n_w_max_aliases == 1:
        return data.loc[data.n_aliases == max_aliases, :]
    elif n_w_max_aliases > 1:
        data = data.loc[data.n_aliases == max_aliases, :].copy()
    
    # take most tags
    max_tags = max(data.n_tags)
    n_w_max_tags = data.loc[data.n_tags == max_tags, :].shape[0]
    if max_tags > 0 and n_w_max_tags == 1:
        return data.loc[data.n_tags == max_tags, :]
    
    # give up
    return None
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# load data and run through the first pass match-per-match
with open('data/interim/mbz_composer_search.json', 'r') as f:
    data = json.load(f)

df = first_pass(data)

# %%
df
# Out:
#                                    area_id       area_name  avg_score  \
# 0     85752fda-13c4-31a3-bee5-0e5cb1f51dad         Germany      100.0
# 1     85752fda-13c4-31a3-bee5-0e5cb1f51dad         Germany      100.0
# 2     caac77d1-a5c8-3e6e-8e27-90b44dcc1446         Austria       88.0
# 3     c6500277-9a3d-349b-bf30-41afdbf42add           Italy      100.0
# 4     caac77d1-a5c8-3e6e-8e27-90b44dcc1446         Austria      100.0
# 5     c6500277-9a3d-349b-bf30-41afdbf42add           Italy      100.0
# 6     85752fda-13c4-31a3-bee5-0e5cb1f51dad         Germany      100.0
# 7     c6500277-9a3d-349b-bf30-41afdbf42add           Italy      100.0
# 8     08310658-51eb-3801-80de-5a0739207115          France      100.0
# 9     caac77d1-a5c8-3e6e-8e27-90b44dcc1446         Austria      100.0
# 10    caac77d1-a5c8-3e6e-8e27-90b44dcc1446         Austria      100.0
# 11    85752fda-13c4-31a3-bee5-0e5cb1f51dad         Germany       89.5
# 12    85752fda-13c4-31a3-bee5-0e5cb1f51dad         Germany      100.0
# 13    85752fda-13c4-31a3-bee5-0e5cb1f51dad         Germany      100.0
# 14    c6500277-9a3d-349b-bf30-41afdbf42add           Italy      100.0
# 15    c6500277-9a3d-349b-bf30-41afdbf42add           Italy      100.0
# 16    5b8a5ee5-0bb3-34cf-9a75-c27c44e341fc         Belgium      100.0
# 17    85752fda-13c4-31a3-bee5-0e5cb1f51dad         Germany      100.0
# 18    8a754a16-0027-3a29-b6d7-2b40ea0481ed  United Kingdom       96.5
# 19    85752fda-13c4-31a3-bee5-0e5cb1f51dad         Germany      100.0
# 20    85752fda-13c4-31a3-bee5-0e5cb1f51dad         Germany      100.0
# 21    85752fda-13c4-31a3-bee5-0e5cb1f51dad         Germany      100.0
# 22    c6500277-9a3d-349b-bf30-41afdbf42add           Italy      100.0
# 23    312bc5bb-7e43-3e63-81c6-b4d712b37b2c         Hungary      100.0
# 24    08310658-51eb-3801-80de-5a0739207115          France      100.0
# 25    489ce91b-6658-3307-9877-795b68554c98   United States       85.5
# 26    5b8a5ee5-0bb3-34cf-9a75-c27c44e341fc         Belgium      100.0
# 27    85752fda-13c4-31a3-bee5-0e5cb1f51dad         Germany      100.0
# 28    08310658-51eb-3801-80de-5a0739207115          France      100.0
# 29    c6500277-9a3d-349b-bf30-41afdbf42add           Italy      100.0
# ...                                    ...             ...        ...
# 2277  a63fbc7f-af00-33c7-8616-3e86df9fc16b            Iran      100.0
# 2278  08310658-51eb-3801-80de-5a0739207115          France      100.0
# 2279  8a754a16-0027-3a29-b6d7-2b40ea0481ed  United Kingdom      100.0
# 2280  8a754a16-0027-3a29-b6d7-2b40ea0481ed  United Kingdom       85.0
# 2281  489ce91b-6658-3307-9877-795b68554c98   United States      100.0
# 2282  489ce91b-6658-3307-9877-795b68554c98   United States      100.0
# 2283                                  None            None      100.0
# 2284                                  None            None      100.0
# 2285                                  None            None      100.0
# 2286  23d10872-f5ae-3f0c-bf55-332788a16ecb          Sweden      100.0
# 2287  08310658-51eb-3801-80de-5a0739207115          France       85.0
# 2288  e1c1215f-dcc0-35b4-b840-d2ca2151593b         Estonia       85.0
# 2289  23d10872-f5ae-3f0c-bf55-332788a16ecb          Sweden       85.0
# 2290                                  None            None       85.0
# 2291  9ed3be5f-d54c-3add-a6a6-76c0cca54fd8   Faroe Islands       85.0
# 2292                                  None            None       85.0
# 2293                                  None            None       85.0
# 2294  8a754a16-0027-3a29-b6d7-2b40ea0481ed  United Kingdom      100.0
# 2295  489ce91b-6658-3307-9877-795b68554c98   United States      100.0
# 2296  489ce91b-6658-3307-9877-795b68554c98   United States      100.0
# 2297  8a754a16-0027-3a29-b6d7-2b40ea0481ed  United Kingdom      100.0
# 2298  48802a32-075a-3805-a183-277c66047693         Iceland       93.0
# 2299  48802a32-075a-3805-a183-277c66047693         Iceland      100.0
# 2300                                  None            None      100.0
# 2301  489ce91b-6658-3307-9877-795b68554c98   United States      100.0
# 2302  489ce91b-6658-3307-9877-795b68554c98   United States      100.0
# 2303                                  None            None      100.0
# 2304  ef1b7cc0-cd26-36f4-8ea0-04d9623786c7     Netherlands      100.0
# 2305  51d34c28-61bf-3d21-849f-7492672a9d44  Czech Republic      100.0
# 2306                                  None            None      100.0
#
#                               beginarea_id         beginarea_name  \
# 0     b86b7e97-c4e2-4ec2-942b-5a6cd8eea1da                   Bonn
# 1     d1a17bfe-b392-4aae-bf67-e6c6987363fe                  Eutin
# 2     ed091849-62dd-4d10-9d40-50594afb1b15             Bratislava
# 3     b3c4f4b8-1a4c-48e6-93db-e278dce26270                 Pesaro
# 4     f0590317-8b42-4498-a2e4-34cc5562fcf8               Salzburg
# 5     0ebe2c1b-f49e-4144-be01-1f146ee6e8b3                Catania
# 6     74601bdf-08ff-4efa-a1ac-d6020853ae53               Dinklage
# 7     0ebe2c1b-f49e-4144-be01-1f146ee6e8b3                Catania
# 8     31eea06c-a794-4138-879d-e633336275a2       Clermont-Ferrand
# 9     28d44913-d1b1-4cc8-8c51-bf80a2a210cf                 Geneva
# 10    afff1a94-a98b-4322-8874-3148139ab6da                   Wien
# 11    94ff83eb-5039-4883-b9ab-cfaba7bc133d                Koblenz
# 12    11a44e18-a2e5-43a9-bee9-aa4f7c83f967                Hamburg
# 13    5d668739-7f88-4062-9bc5-11a90e838310           Braunschweig
# 14    b92356fa-87ef-47dd-a47e-581149e0a676                   Fano
# 15    dcc53548-12ed-4a6d-b63b-5f17a74b0ad0                Bergamo
# 16    747186c0-063c-4be4-a237-91d840609a53               Verviers
# 17    9dcff3f1-a42f-49bb-ada6-82d7a6afef16                 Zittau
# 18    3ce737cb-f5bb-403d-a98a-e0602670229f              Sheffield
# 19    3fa14c05-a6a7-43d2-b2fe-74c69374d1ff             Rüdersdorf
# 20    b86b7e97-c4e2-4ec2-942b-5a6cd8eea1da                   Bonn
# 21    fe7eb3c0-9e64-4e11-8555-c98f4539c370              Messkirch
# 22    2b397313-0d04-4167-b9a8-914f16935d4a               Florence
# 23    f1ac379f-8cd3-45c3-8da0-80c429b36c5e               Budapest
# 24    6decc63f-52c6-4b00-a8e6-1f76958c8994                  Givet
# 25    3c5a0506-d852-4e96-8d1e-d8126328f3be            New Orleans
# 26    38f97ed2-6128-4da3-be1d-423d75331ff2                 Leuven
# 27    38693e55-f5d3-4dc5-99af-debd2a8c1c87                Münster
# 28    d427e247-565b-40a5-9195-b39a85b4502f    La Côte-Saint-André
# 29    53ef3e36-f288-4ef5-b4cf-1725f7fc77d4             Le Roncole
# ...                                    ...                    ...
# 2277  aaa5899f-f0b7-4bc1-bae4-aba7f6770402                 Tehran
# 2278  dc10c22b-e510-4006-8b7f-fecb4f36436e                  Paris
# 2279                                  None                   None
# 2280  8a754a16-0027-3a29-b6d7-2b40ea0481ed         United Kingdom
# 2281                                  None                   None
# 2282                                  None                   None
# 2283                                  None                   None
# 2284                                  None                   None
# 2285                                  None                   None
# 2286  1127ddc2-eab3-4662-8718-6adbdeea3b10              Stockholm
# 2287                                  None                   None
# 2288                                  None                   None
# 2289  d44882c0-a6a9-474f-b62a-d813a442f4b5  Danderyd municipality
# 2290                                  None                   None
# 2291                                  None                   None
# 2292                                  None                   None
# 2293  39d41edd-5b4e-496e-a080-077283989dd0                 Mobile
# 2294  f03d09b3-39dc-4083-afd6-159e3f0d462f                 London
# 2295  1f40c6e1-47ba-4e35-996f-fe6ee5840e62            Los Angeles
# 2296  1f40c6e1-47ba-4e35-996f-fe6ee5840e62            Los Angeles
# 2297  40d758a4-b7c2-40f3-b439-5efbd2a3b038                Bristol
# 2298  48802a32-075a-3805-a183-277c66047693                Iceland
# 2299  e498a3ef-704c-462e-b144-6e6fc108a6f2              Reykjavík
# 2300                                  None                   None
# 2301                                  None                   None
# 2302  725210c4-3f89-4f49-a508-794e92f700ef               Damascus
# 2303                                  None                   None
# 2304  8722e2f8-e531-4806-a645-71b3263ac85f               Schiedam
# 2305  fa083fd0-a55d-4d32-a5c5-05de83523e30                 Přerov
# 2306                                  None                   None
#
#                       cleanname  composerid country  disambig_composer  \
# 0          beethoven ludwig van           0      DE              False
# 1          weber carl maria von           1      DE              False
# 2                 hummel johann           2      AT              False
# 3             rossini gioachino           4      IT               True
# 4       mozart wolfgang amadeus           5      AT               True
# 5              bellini vincenzo           7      IT               True
# 6              romberg bernhard           8      DE              False
# 7               pacini giovanni           9      IT              False
# 8                 onslow george          10      FR              False
# 9            thalberg sigismond          11      AT              False
# 10                   herz henri          12      AT              False
# 11       lindpaintner peter von          13      DE              False
# 12            mendelssohn felix          15      DE              False
# 13                  spohr louis          16      DE              False
# 14              nini alessandro          17      IT              False
# 15            donizetti gaetano          18      IT               True
# 16             vieuxtemps henri          22      BE              False
# 17    marschner heinrich august          23      DE              False
# 18    bennett william sterndale          24      GB              False
# 19            meyerbeer giacomo          25      DE              False
# 20               ries ferdinand          26      DE              False
# 21            kreutzer conradin          27      DE              False
# 22              cherubini luigi          28      IT              False
# 23               heller stephen          31      HU              False
# 24        mehul etienne nicolas          32      FR              False
# 25              loder george jr          33      US              False
# 26     beriot charlesauguste de          34      BE              False
# 27     furstenau anton bernhard          36      DE              False
# 28               berlioz hector          37      FR              False
# 29               verdi giuseppe          38      IT               True
# ...                         ...         ...     ...                ...
# 2277           ranjbaran behzad        2747      IR              False
# 2278            renie henriette        2749      FR              False
# 2279               graham peter        2750      GB               True
# 2280              gates dorothy        2752      GB              False
# 2281                  anonymous        2753      US              False
# 2282                  anonymous        2753      US              False
# 2283                  anonymous        2753    None              False
# 2284                  anonymous        2753    None              False
# 2285                  anonymous        2753    None              False
# 2286               leidzen erik        2754      SE              False
# 2287            araujo benjamin        2755      FR              False
# 2288            araujo benjamin        2755      EE              False
# 2289            araujo benjamin        2755      SE              False
# 2290            araujo benjamin        2755    None              False
# 2291            araujo benjamin        2755      FO              False
# 2292            araujo benjamin        2755    None              False
# 2293            araujo benjamin        2755    None              False
# 2294          hurlstone william        2762      GB              False
# 2295      thomas michael tilson        2765      US              False
# 2296            broughton bruce        2766      US              False
# 2297               davies tansy        2767      GB              False
# 2298       thorvaldsdottir anna        2768      IS              False
# 2299                      bjork        2769      IS              False
# 2300                  pluta sam        2771    None              False
# 2301               fulmer david        2772      US              False
# 2302                azmeh kinan        2773      US              False
# 2303               perez edward        2774    None              False
# 2304               roukens joey        2776      NL               True
# 2305               klein gideon        2778      CZ              False
# 2306           norpoth johnpaul        2711    None              False
#
#                                 endarea_id    ...     lifespan_end  \
# 0     afff1a94-a98b-4322-8874-3148139ab6da    ...       1827-03-26
# 1     f03d09b3-39dc-4083-afd6-159e3f0d462f    ...       1826-06-05
# 2     c7644e45-dec4-43fd-aad6-35036b8e911d    ...       1837-10-17
# 3     dc10c22b-e510-4006-8b7f-fecb4f36436e    ...       1868-11-13
# 4     afff1a94-a98b-4322-8874-3148139ab6da    ...       1791-12-05
# 5     c65960ba-69b5-494f-b7d6-8dea87a3986c    ...       1835-09-23
# 6     11a44e18-a2e5-43a9-bee9-aa4f7c83f967    ...       1841-08-13
# 7     36d9876d-38e9-49b4-9024-16055a9e1778    ...       1867-12-06
# 8     31eea06c-a794-4138-879d-e633336275a2    ...       1853-10-03
# 9     86fbdd3c-aaac-4aed-916a-b361f7e1a8de    ...       1871-04-27
# 10    dc10c22b-e510-4006-8b7f-fecb4f36436e    ...       1888-01-05
# 11    4e944162-f91a-4c8e-8448-f7fe72c9d31f    ...       1856-08-21
# 12    20619e36-fca8-4499-bcc8-be01a3ea3e41    ...       1847-11-04
# 13    7b612d6a-36ca-49b3-a321-aa0d07445e9e    ...       1859-10-22
# 14    dcc53548-12ed-4a6d-b63b-5f17a74b0ad0    ...       1880-12-27
# 15    dcc53548-12ed-4a6d-b63b-5f17a74b0ad0    ...       1848-04-08
# 16    bbe3b20f-c458-44bd-bc36-e42ece90d159    ...       1881-06-06
# 17    eca79b55-a6c4-4078-a383-8353271ee81e    ...       1861-12-14
# 18    48d08ee1-db45-4566-bb1d-c47ab6dbaf98    ...       1875-02-01
# 19    dc10c22b-e510-4006-8b7f-fecb4f36436e    ...       1864-05-02
# 20    16560d3e-358b-4869-8a6d-727db2ee7b69    ...       1838-01-13
# 21    9c612199-d66f-4109-aedc-67ab26e0a43b    ...       1849-12-14
# 22    dc10c22b-e510-4006-8b7f-fecb4f36436e    ...       1842-03-15
# 23    dc10c22b-e510-4006-8b7f-fecb4f36436e    ...       1888-01-14
# 24    dc10c22b-e510-4006-8b7f-fecb4f36436e    ...       1817-10-18
# 25                                    None    ...             None
# 26    dc10c22b-e510-4006-8b7f-fecb4f36436e    ...       1870-04-08
# 27    624f2956-bfdb-43a9-8924-9aadb812ee04    ...       1852-11-18
# 28    dc10c22b-e510-4006-8b7f-fecb4f36436e    ...       1869-03-08
# 29    d793f202-faf0-4de8-83e2-9ddfca54a35f    ...       1901-01-27
# ...                                    ...    ...              ...
# 2277                                  None    ...             None
# 2278  dc10c22b-e510-4006-8b7f-fecb4f36436e    ...       1956-03-01
# 2279                                  None    ...             None
# 2280                                  None    ...             None
# 2281                                  None    ...             None
# 2282                                  None    ...             None
# 2283                                  None    ...             None
# 2284                                  None    ...             None
# 2285                                  None    ...             None
# 2286  74e50e58-5deb-4b99-93a2-decbb365c07f    ...             1962
# 2287                                  None    ...             None
# 2288                                  None    ...             None
# 2289                                  None    ...             None
# 2290                                  None    ...             None
# 2291                                  None    ...             None
# 2292                                  None    ...             None
# 2293                                  None    ...             None
# 2294  f03d09b3-39dc-4083-afd6-159e3f0d462f    ...       1906-05-30
# 2295                                  None    ...             None
# 2296                                  None    ...             None
# 2297                                  None    ...             None
# 2298                                  None    ...             None
# 2299                                  None    ...             None
# 2300                                  None    ...             None
# 2301                                  None    ...             None
# 2302                                  None    ...             None
# 2303                                  None    ...             None
# 2304                                  None    ...             None
# 2305  34cee74b-bb90-4f7d-82c1-63ec20007145    ...       1945-01-27
# 2306                                  None    ...             None
#
#      lifespan_ended                                 mbzid  n_aliases n_tags  \
# 0              True  1f9df192-a621-4f54-8850-2c5373b7eac9         28     20
# 1              True  c2d17829-1424-435b-9386-c77d3a920abe          9      5
# 2              True  f7ef501b-2bc0-4083-ac52-3518255883a2          4      3
# 3              True  846be3c9-5f94-46ab-97b9-531335dd3658         13      7
# 4              True  b972f589-fb0e-474e-b64a-803b0364fa75         24     16
# 5              True  6f5bfd20-84cc-4879-8a40-05631ad576c7          6      6
# 6              True  0040c89b-f2e6-4bc3-b75d-5152fb0c890e          0      2
# 7              True  9ee75435-3d4a-4455-bab6-aed7f7f8b2bc          0      0
# 8              True  d862c725-08b8-45bd-881b-3e6a9f295366          1      3
# 9              True  480aa5f2-97e6-4e79-a364-6629d7b63b55          0      0
# 10             True  bc82f076-2d4f-478d-809a-04c8c80fa47b          0      1
# 11             True  985a0e7d-d852-4caf-8970-1616baf40f9e          1      0
# 12             True  0e85eb79-1c05-44ba-827c-7b259a3d941a         28     10
# 13             True  328e23ea-d79c-4c58-bd20-bbdd3f64bb8e          2      4
# 14             True  534cbe70-e6f5-4094-9cf0-3c6969423ba8          0      0
# 15             True  b8ecf204-6be8-4041-ab11-6d9971ea2711          7      3
# 16             True  a3552f21-dd32-4ff7-8310-dbc102f6a224          0      5
# 17             True  24e546a2-d720-4ca7-b127-4919745e8faa          1      0
# 18             True  4844cd51-00c4-4609-bec4-fb89b6d9693c          2      1
# 19             True  e2e5fec1-d87b-4b48-81b1-7e9ab074f348          1      1
# 20             True  ba4a674d-57f0-440b-82f9-798965c05dd9          0      1
# 21             True  5634730d-71f7-4181-8067-15a3f1700812          0      4
# 22             True  375d52ad-5b7a-4f96-80e2-6d9ad13f5160          1      3
# 23             True  ce59c840-fdb7-4e9c-b023-d924c73a9c8d          1      1
# 24             True  43cfe3a1-5de4-4538-98ee-3203843d9803          2      0
# 25             None  672633b9-c0dc-4eb0-bf81-473d7d6b0723          0      0
# 26             True  77d849e1-aa95-4651-bdac-bfaecd152e43          0      4
# 27             True  8eb58c23-a103-42a7-a320-6b9d6c9013a1          0      0
# 28             True  274774a7-1cde-486a-bc3d-375ec54d552d         11      7
# 29             True  f1bedf1f-4445-4651-9c35-f4a3f3860a13         13      6
# ...             ...                                   ...        ...    ...
# 2277           None  8ca321f0-9ae5-49e0-8ba6-c60f32c8cb8a          0      0
# 2278           True  574ce33b-4d82-405d-b1cd-798740ba0e60          0      0
# 2279           None  c128ba43-6c2d-4171-8a4c-990363102936          0      1
# 2280           None  897f98ea-ee0d-40e1-9ba3-9ef11aa6ef9c          0      0
# 2281           None  404c85cc-2f04-4bb2-afba-62462146eaf9          0      0
# 2282           None  e362ac38-a075-41cd-bcb1-a20e0a32c1f4          0      0
# 2283           None  d4ba7bd9-6412-4b33-8a91-c0212c8e64cd          0      0
# 2284           None  2a2cc925-568d-48d8-b232-683de5ce6df4          0      0
# 2285           None  cd01db3c-8517-48d6-9771-412005094e9b          0      0
# 2286           True  47d533fc-8d64-444d-826b-c9390857b4a3          0      0
# 2287           None  cb16f250-1c23-4a89-83e4-bee797623679          0      0
# 2288           None  67f8bd70-be98-4b41-97f9-208a299a0db2          0      0
# 2289           None  811e6599-d337-4350-8897-6ff3a9a0b079          0      0
# 2290           None  1fb3b900-6d91-475e-900d-fa6d286fa094          0      0
# 2291           None  5949eabb-ca9a-4068-ab8d-7abfb8b486fc          0      0
# 2292           None  f0512f1a-343d-4b4a-a46b-cb2bc535ec71          0      0
# 2293           None  c5bd9514-bce7-4826-9e29-496e62db9af6          0      0
# 2294           True  bee20018-031c-47fc-866e-dc4dbfaf02f3          0      0
# 2295           None  f6df125a-a83c-4161-8cbe-48f4a3a7cad5          0      4
# 2296           None  8efdd66f-98b8-4cfd-95da-62af1b0d85c9          2      1
# 2297           None  6da13f9f-6bb5-4681-a745-7c60cfef5e04          0      2
# 2298           None  e9b7623e-d133-4c74-b7a6-2cd025206b52          1      1
# 2299           None  87c5dedd-371d-4a53-9f7f-80522fb7f3cb         10     29
# 2300           None  7c4abfc8-689e-4b96-ac01-575149af827f          0      0
# 2301           None  8251aac4-90bf-46a2-83c8-d9dfaea2854d          0      0
# 2302           None  31d46bc1-2e7c-4192-a013-73f6e46ecbcb          1      0
# 2303           None  1b5fe1be-9d4b-423b-9cc9-906061d954cd          0      0
# 2304           None  e90a8099-9670-45bb-b8ec-dc63bb84c367          0      0
# 2305           True  19b48f5d-ec28-4c88-8116-f75d2fb8b013          0      0
# 2306           None  0446515a-d1a7-4956-9c50-d6b81770707c          0      0
#
#      pr_score                    searchname                         sortname  \
# 0         100       Beethoven,  Ludwig  van            Beethoven, Ludwig van
# 1         100       Weber,  Carl  Maria Von            Weber, Carl Maria von
# 2         100               Hummel,  Johann           Hummel, Johann Nepomuk
# 3         100           Rossini,  Gioachino               Rossini, Gioachino
# 4         100    Mozart,  Wolfgang  Amadeus         Mozart, Wolfgang Amadeus
# 5         100            Bellini,  Vincenzo                Bellini, Vincenzo
# 6         100            Romberg,  Bernhard                Romberg, Bernhard
# 7         100             Pacini,  Giovanni                 Pacini, Giovanni
# 8         100               Onslow,  George                   Onslow, George
# 9         100          Thalberg,  Sigismond              Thalberg, Sigismond
# 10        100                  Herz,  Henri                      Herz, Henri
# 11         91     Lindpaintner,  Peter  Von    Lindpaintner, Peter Josef von
# 12        100           Mendelssohn,  Felix               Mendelssohn, Felix
# 13        100                 Spohr,  Louis                     Spohr, Louis
# 14        100             Nini,  Alessandro                 Nini, Alessandro
# 15        100           Donizetti,  Gaetano               Donizetti, Gaetano
# 16        100            Vieuxtemps,  Henri                Vieuxtemps, Henri
# 17        100  Marschner,  Heinrich  August       Marschner, Heinrich August
# 18        100  Bennett,  William  Sterndale  Bennett, William Sterndale, Sir
# 19        100           Meyerbeer,  Giacomo               Meyerbeer, Giacomo
# 20        100              Ries,  Ferdinand                  Ries, Ferdinand
# 21        100           Kreutzer,  Conradin               Kreutzer, Conradin
# 22        100             Cherubini,  Luigi                 Cherubini, Luigi
# 23        100              Heller,  Stephen                  Heller, Stephen
# 24        100      Mehul,  Etienne  Nicolas           Méhul, Étienne Nicolas
# 25         87           Loder,  George, Jr.              Porter, George, Jr.
# 26        100  Beriot,  Charles-Auguste  de       Bériot, Charles-Auguste de
# 27        100   Furstenau,  Anton  Bernhard        Fürstenau, Anton Bernhard
# 28        100              Berlioz,  Hector                  Berlioz, Hector
# 29        100              Verdi,  Giuseppe                  Verdi, Giuseppe
# ...       ...                           ...                              ...
# 2277      100            Ranjbaran,  Behzad                Ranjbaran, Behzad
# 2278      100             Renie,  Henriette                 Renié, Henriette
# 2279      100                Graham,  Peter                    Graham, Peter
# 2280      100               Gates,  Dorothy                          Dorothy
# 2281      100                    Anonymous,                        Anonymous
# 2282      100                    Anonymous,                        Anonymous
# 2283      100                    Anonymous,                        Anonymous
# 2284      100                    Anonymous,                        Anonymous
# 2285      100                    Anonymous,                        Anonymous
# 2286      100                Leidzen,  Erik                    Leidzén, Erik
# 2287      100             Araujo,  Benjamin                         Benjamin
# 2288      100             Araujo,  Benjamin                         Benjamin
# 2289      100             Araujo,  Benjamin                         Benjamin
# 2290      100             Araujo,  Benjamin                         Benjamin
# 2291      100             Araujo,  Benjamin                         Benjamin
# 2292      100             Araujo,  Benjamin                         Benjamin
# 2293      100             Araujo,  Benjamin                         Benjamin
# 2294      100           Hurlstone,  William               Hurlstone, William
# 2295      100      Thomas,  Michael  Tilson           Thomas, Michael Tilson
# 2296      100             Broughton,  Bruce                 Broughton, Bruce
# 2297      100                Davies,  Tansy                    Davies, Tansy
# 2298       86        Thorvaldsdottir,  Anna             Anna Thorvaldsdottir
# 2299      100                        Bjork,                            Björk
# 2300      100                   Pluta,  Sam                       Pluta, Sam
# 2301      100                Fulmer,  David                    Fulmer, David
# 2302      100                 Azmeh,  Kinan                     Azmeh, Kinan
# 2303      100                Perez,  Edward                    Perez, Edward
# 2304      100                Roukens,  Joey                    Roukens, Joey
# 2305      100                Klein,  Gideon                    Klein, Gideon
# 2306      100           Norpoth,  John-Paul               Norpoth, John-Paul
#
#       tag_composer  tsr_score
# 0             True        100
# 1             True        100
# 2             True         76
# 3             True        100
# 4             True        100
# 5             True        100
# 6             True        100
# 7            False        100
# 8             True        100
# 9            False        100
# 10            True        100
# 11           False         88
# 12            True        100
# 13            True        100
# 14           False        100
# 15            True        100
# 16            True        100
# 17           False        100
# 18            True         93
# 19           False        100
# 20           False        100
# 21            True        100
# 22            True        100
# 23           False        100
# 24           False        100
# 25           False         84
# 26            True        100
# 27           False        100
# 28            True        100
# 29            True        100
# ...            ...        ...
# 2277         False        100
# 2278         False        100
# 2279         False        100
# 2280         False         70
# 2281         False        100
# 2282         False        100
# 2283         False        100
# 2284         False        100
# 2285         False        100
# 2286         False        100
# 2287         False         70
# 2288         False         70
# 2289         False         70
# 2290         False         70
# 2291         False         70
# 2292         False         70
# 2293         False         70
# 2294         False        100
# 2295         False        100
# 2296         False        100
# 2297          True        100
# 2298          True        100
# 2299         False        100
# 2300         False        100
# 2301         False        100
# 2302         False        100
# 2303         False        100
# 2304         False        100
# 2305         False        100
# 2306         False        100
#
# [2307 rows x 25 columns]

# %%
# split off a dataframe of dupes
compcounts = df.composerid.value_counts()
idx_multicomps = df.composerid.isin(compcounts[compcounts >= 2].index)

finaldf = df.loc[~idx_multicomps].copy()
dupeddf = df.loc[idx_multicomps].copy()

# evaluate each set of potential composer matches
best_matches = dupeddf.groupby('composerid').apply(choose_best_match)

# and rejoin to main dataset
finaldf = finaldf.append(best_matches,ignore_index=True)
finaldf.set_index('composerid', inplace=True)

# %%
final_cols = [
    'mbzid',
    'sortname', 'gender',
    'country', 'area_id', 'area_name', 'beginarea_id', 'endarea_id',
    'lifespan_begin', 'lifespan_end', 'lifespan_ended',
    'n_aliases', 'n_tags', 'tag_composer'
]

# %%
finaldf[final_cols].to_csv('data/tmp/mbz_partial.txt', sep='\t')

# %%
finaldf.head()
# Out:
#                                          area_id area_name  avg_score  \
# composerid
# 0           85752fda-13c4-31a3-bee5-0e5cb1f51dad   Germany      100.0
# 1           85752fda-13c4-31a3-bee5-0e5cb1f51dad   Germany      100.0
# 2           caac77d1-a5c8-3e6e-8e27-90b44dcc1446   Austria       88.0
# 4           c6500277-9a3d-349b-bf30-41afdbf42add     Italy      100.0
# 5           caac77d1-a5c8-3e6e-8e27-90b44dcc1446   Austria      100.0
#
#                                     beginarea_id beginarea_name  \
# composerid
# 0           b86b7e97-c4e2-4ec2-942b-5a6cd8eea1da           Bonn
# 1           d1a17bfe-b392-4aae-bf67-e6c6987363fe          Eutin
# 2           ed091849-62dd-4d10-9d40-50594afb1b15     Bratislava
# 4           b3c4f4b8-1a4c-48e6-93db-e278dce26270         Pesaro
# 5           f0590317-8b42-4498-a2e4-34cc5562fcf8       Salzburg
#
#                           cleanname country  disambig_composer  \
# composerid
# 0              beethoven ludwig van      DE              False
# 1              weber carl maria von      DE              False
# 2                     hummel johann      AT              False
# 4                 rossini gioachino      IT               True
# 5           mozart wolfgang amadeus      AT               True
#
#                                       endarea_id endarea_name    ...      \
# composerid                                                       ...
# 0           afff1a94-a98b-4322-8874-3148139ab6da         Wien    ...
# 1           f03d09b3-39dc-4083-afd6-159e3f0d462f       London    ...
# 2           c7644e45-dec4-43fd-aad6-35036b8e911d       Weimar    ...
# 4           dc10c22b-e510-4006-8b7f-fecb4f36436e        Paris    ...
# 5           afff1a94-a98b-4322-8874-3148139ab6da         Wien    ...
#
#            lifespan_end lifespan_ended                                 mbzid  \
# composerid
# 0            1827-03-26           True  1f9df192-a621-4f54-8850-2c5373b7eac9
# 1            1826-06-05           True  c2d17829-1424-435b-9386-c77d3a920abe
# 2            1837-10-17           True  f7ef501b-2bc0-4083-ac52-3518255883a2
# 4            1868-11-13           True  846be3c9-5f94-46ab-97b9-531335dd3658
# 5            1791-12-05           True  b972f589-fb0e-474e-b64a-803b0364fa75
#
#            n_aliases n_tags pr_score                  searchname  \
# composerid
# 0                 28     20      100     Beethoven,  Ludwig  van
# 1                  9      5      100     Weber,  Carl  Maria Von
# 2                  4      3      100             Hummel,  Johann
# 4                 13      7      100         Rossini,  Gioachino
# 5                 24     16      100  Mozart,  Wolfgang  Amadeus
#
#                             sortname  tag_composer  tsr_score
# composerid
# 0              Beethoven, Ludwig van          True        100
# 1              Weber, Carl Maria von          True        100
# 2             Hummel, Johann Nepomuk          True         76
# 4                 Rossini, Gioachino          True        100
# 5           Mozart, Wolfgang Amadeus          True        100
#
# [5 rows x 24 columns]

# %% [markdown]
# ### things to get from mbz
# - fill out country where only area is available
# - number of works
# - number of recordings (but watch out for conductors?)
# - main area? is that a thing?
# - era of birth
# - data of death [for comparison with first performance]

# %%
finaldf.loc[finaldf.country.isnull()].apply(lambda x: str(x.country) + str(x.area_name), axis=1).value_counts()
# Out:
# NoneNone             132
# NoneEngland           12
# NoneQuebec             3
# NoneLondon             1
# NoneOhio               1
# NoneMassachusetts      1
# NoneSanto Domingo      1
# NoneVentura            1
# NoneSanta Barbara      1
# NoneNew York           1
# NoneInnsbruck          1
# NoneFlanders           1
# NoneEast Sussex        1
# NoneJerusalem          1
# NoneDayton             1
# NoneBoston             1
# dtype: int64

# %%
finaldf[finaldf.country.isnull() & finaldf.area_id.notnull()]
# Out:
#                                          area_id      area_name  avg_score  \
# composerid
# 404         2ea52ae1-00ee-406e-a8f1-50fb88554d24       Flanders      100.0
# 411         9d5dd675-3cf4-4296-9e39-67865ebee758        England      100.0
# 412         9d5dd675-3cf4-4296-9e39-67865ebee758        England      100.0
# 528         9d5dd675-3cf4-4296-9e39-67865ebee758        England      100.0
# 549         9d5dd675-3cf4-4296-9e39-67865ebee758        England      100.0
# 556         9d5dd675-3cf4-4296-9e39-67865ebee758        England      100.0
# 980         9d5dd675-3cf4-4296-9e39-67865ebee758        England       94.0
# 1030        9d5dd675-3cf4-4296-9e39-67865ebee758        England      100.0
# 1107        f03d09b3-39dc-4083-afd6-159e3f0d462f         London      100.0
# 1121        a510b9b1-404d-4e23-8db8-0f6585909ed8         Quebec      100.0
# 1205        9d5dd675-3cf4-4296-9e39-67865ebee758        England      100.0
# 1459        61b6a12e-4751-4fe3-b40d-ecb84f29736c    East Sussex      100.0
# 1778        f12f47f9-daf9-4eec-a30e-e8a9e9bd4124  Santa Barbara      100.0
# 1870        e331bfdf-b908-429c-a79b-710cf9c06abb         Boston       97.0
# 2028        9d5dd675-3cf4-4296-9e39-67865ebee758        England      100.0
# 2043        9d5dd675-3cf4-4296-9e39-67865ebee758        England      100.0
# 2052        9d5dd675-3cf4-4296-9e39-67865ebee758        England      100.0
# 2137        1faa5690-6a98-43d9-aeff-10ae4be13df9  Santo Domingo      100.0
# 2372        08a08584-b3a5-473a-b52e-00f5fd9b0649      Jerusalem      100.0
# 2515        a510b9b1-404d-4e23-8db8-0f6585909ed8         Quebec      100.0
# 2523        0a19e07a-81e0-4bfe-a103-62c15ec45ecd      Innsbruck      100.0
# 2668        74e50e58-5deb-4b99-93a2-decbb365c07f       New York       90.0
# 2706        a510b9b1-404d-4e23-8db8-0f6585909ed8         Quebec      100.0
# 2718        0573177b-9ff9-4643-80bc-ed2513419267           Ohio      100.0
# 2722        a55188f6-e976-499b-97b2-735985458216         Dayton       87.0
# 2740        05f68b4c-10f3-49b5-b28c-260a1b707043  Massachusetts      100.0
# 1369        1ba8f726-6c07-4ecc-b9ac-bd13195306dd        Ventura      100.0
# 1908        9d5dd675-3cf4-4296-9e39-67865ebee758        England      100.0
#
#                                     beginarea_id beginarea_name  \
# composerid
# 404         7f24b77b-abe7-42d9-b79c-ee09bbf5c83c          Liège
# 411         aff4808a-7e67-49ab-8d51-af0864c824e0       Somerset
# 412                                         None           None
# 528         24404231-7564-4b11-9168-95dd148049a7           Kent
# 549         f03d09b3-39dc-4083-afd6-159e3f0d462f         London
# 556                                         None           None
# 980         f03d09b3-39dc-4083-afd6-159e3f0d462f         London
# 1030        f03d09b3-39dc-4083-afd6-159e3f0d462f         London
# 1107        12c9edfe-2c1f-48ef-9d38-82494a9350a9         Wirral
# 1121        c3cc624e-b963-49cf-ad0b-e318cb341963       Montreal
# 1205        dccd77b2-bd3d-49eb-a98f-fd58e87f481e           Rome
# 1459                                        None           None
# 1778        7eb6a212-023b-4a10-a95a-5de38016228a         Peoria
# 1870        eb4a386e-1178-4e3a-a371-30418dd6fd2e      The Bronx
# 2028        40868657-ef80-4b66-88ba-263ecac1b9a1         Harrow
# 2043        304775d9-49c7-4e15-b538-dce05d6b557e     Corringham
# 2052                                        None           None
# 2137        1faa5690-6a98-43d9-aeff-10ae4be13df9  Santo Domingo
# 2372        08a08584-b3a5-473a-b52e-00f5fd9b0649      Jerusalem
# 2515        c3cc624e-b963-49cf-ad0b-e318cb341963       Montreal
# 2523        0a19e07a-81e0-4bfe-a103-62c15ec45ecd      Innsbruck
# 2668        71bbafaa-e825-3e15-8ca9-017dcad1748b         Canada
# 2706                                        None           None
# 2718                                        None           None
# 2722                                        None           None
# 2740        77f6b33a-5c5c-4ba5-9a33-9d8875f67a60      Lancaster
# 1369        1f40c6e1-47ba-4e35-996f-fe6ee5840e62    Los Angeles
# 1908        f03d09b3-39dc-4083-afd6-159e3f0d462f         London
#
#                          cleanname country  disambig_composer  \
# composerid
# 404               arcadelt jacques    None               True
# 411                      bull john    None               True
# 412                  farnaby giles    None              False
# 528                  hinton arthur    None               True
# 549            horn charles edward    None              False
# 556                    wilbye john    None              False
# 980                barbirolli john    None              False
# 1030        glover charles william    None              False
# 1107                   baxter phil    None              False
# 1121                 mathieu andre    None               True
# 1205                clementi muzio    None              False
# 1459             richardson albert    None              False
# 1778                johnston bruce    None              False
# 1870               williams julius    None              False
# 2028                clarke rebecca    None              False
# 2043           turnage markanthony    None               True
# 2052                pygott richard    None              False
# 2137                 camilo michel    None              False
# 2372                grossman david    None              False
# 2515             hamelin marcandre    None              False
# 2523          staud johannes maria    None              False
# 2668               di castri zosha    None               True
# 2706                 jones jeremie    None              False
# 2718                   ainger marc    None              False
# 2722                  nichols john    None              False
# 2740               kihlstedt carla    None              False
# 1369                     scott tom    None              False
# 1908               benjamin george    None              False
#
#                                       endarea_id endarea_name    ...      \
# composerid                                                       ...
# 404         dc10c22b-e510-4006-8b7f-fecb4f36436e        Paris    ...
# 411         c02ebe2f-ecf0-4671-9f09-d997c0effb9a      Antwerp    ...
# 412         f03d09b3-39dc-4083-afd6-159e3f0d462f       London    ...
# 528         9d5dd675-3cf4-4296-9e39-67865ebee758      England    ...
# 549         e331bfdf-b908-429c-a79b-710cf9c06abb       Boston    ...
# 556                                         None         None    ...
# 980         f03d09b3-39dc-4083-afd6-159e3f0d462f       London    ...
# 1030                                        None         None    ...
# 1107                                        None         None    ...
# 1121                                        None         None    ...
# 1205        eb1f7d4b-4aad-4939-98ab-f8bbcbec5ad8      Evesham    ...
# 1459                                        None         None    ...
# 1778                                        None         None    ...
# 1870                                        None         None    ...
# 2028        74e50e58-5deb-4b99-93a2-decbb365c07f     New York    ...
# 2043                                        None         None    ...
# 2052                                        None         None    ...
# 2137                                        None         None    ...
# 2372                                        None         None    ...
# 2515                                        None         None    ...
# 2523                                        None         None    ...
# 2668                                        None         None    ...
# 2706                                        None         None    ...
# 2718                                        None         None    ...
# 2722                                        None         None    ...
# 2740                                        None         None    ...
# 1369                                        None         None    ...
# 1908                                        None         None    ...
#
#            lifespan_end lifespan_ended                                 mbzid  \
# composerid
# 404                1568           True  673a374b-c873-45cc-af91-aefc76304d59
# 411          1628-03-12           True  ca013e83-6a0a-4ce1-9b35-baaad4e697e0
# 412             1640-11           True  5a59cfb0-45e4-4fa8-8604-2682aad19356
# 528          1941-08-11           True  9a564dfe-a4ed-4daa-9323-9c101c4c23bc
# 549          1849-10-21           True  904acb1c-dc70-49b5-84e8-101195182782
# 556                1638           True  f04b1bdd-d3cf-49d0-a860-f6c8554eac25
# 980          1970-07-29           True  6af449ad-010c-4dc4-afcb-9866cfe619df
# 1030         1863-03-23           True  573b7449-5d04-4d59-8ee5-c839898ee1b7
# 1107               None           None  87c4a3f6-79ea-46f5-b176-8b9cc902f839
# 1121         1968-06-02           True  2507a669-e4e8-4a22-aa8c-7d5e59d51a46
# 1205         1832-03-10           True  25f46ed2-ac8a-4428-ad09-5a3fa5162086
# 1459               None           True  8ccaffde-fe06-42d1-8467-608c1818d077
# 1778               None           None  38bcc90c-2a59-4e62-ac5a-8034cd49ae44
# 1870               None           None  396cbff7-e0d4-4f51-85b5-bfb8592698b9
# 2028         1979-10-13           True  876477d7-f8a8-46a8-9f19-56b07dfe2cf8
# 2043               None           None  c5ed9685-423f-4fe5-bbf3-e31ad25002ae
# 2052               1549           True  584f960b-eb41-4c70-a26a-d16dd04d894b
# 2137               None           None  57829f93-1815-436e-8e9e-55eb788a6f54
# 2372               None           None  7b0d2fc6-1c24-4ec7-bad7-10fc045e03c8
# 2515               None           None  28bdba1f-35c9-4c13-a728-7a72ea37b3ea
# 2523               None           None  3d79195a-fbc8-4dd6-aada-103df1cd29b0
# 2668               None           None  bad76f3d-abbd-496c-bfc3-5fd5934a3ecd
# 2706               None           None  427f8c58-d5dd-4d69-ac89-a15e337c2fbd
# 2718               None           None  ced98aa1-2f4c-496a-900a-7e2f25a8494e
# 2722               None           None  90cf1fff-22bd-4c0a-b2f0-8af2eda1e0ec
# 2740               None           None  4814e187-1b5a-424f-91d4-178750744698
# 1369               None           None  901434fc-5ec8-41a1-af59-6ded7de8a9d2
# 1908               None           None  5d625cf7-0963-42bd-8488-d524758194ed
#
#            n_aliases n_tags pr_score                 searchname  \
# composerid
# 404                3      2      100         Arcadelt,  Jacques
# 411                1      1      100                Bull,  John
# 412                1      2      100            Farnaby,  Giles
# 528                0      0      100            Hinton,  Arthur
# 549                1      0      100     Horn,  Charles  Edward
# 556                0      1      100              Wilbye,  John
# 980                2      3      100          Barbirolli,  John
# 1030               1      0      100  Glover,  Charles  William
# 1107               0      0      100              Baxter,  Phil
# 1121               1      1      100            Mathieu,  Andre
# 1205               0      3      100           Clementi,  Muzio
# 1459               0      0      100        Richardson,  Albert
# 1778               2      0      100           Johnston,  Bruce
# 1870               0      0      100          Williams,  Julius
# 2028               0      0      100           Clarke,  Rebecca
# 2043               0      4      100     Turnage,  Mark-Anthony
# 2052               0      1      100           Pygott,  Richard
# 2137               1      3      100            Camilo,  Michel
# 2372               0      0      100           Grossman,  David
# 2515               1      3      100       Hamelin,  Marc-André
# 2523               0      0      100    Staud,  Johannes  Maria
# 2668               0      0       80          Di Castri,  Zosha
# 2706               0      0      100            Jones,  Jeremie
# 2718               0      0      100              Ainger,  Marc
# 2722               0      0       74             Nichols,  John
# 2740               0      0      100          Kihlstedt,  Carla
# 1369               2      0      100                Scott,  Tom
# 1908               0      1      100          Benjamin,  George
#
#                            sortname  tag_composer  tsr_score
# composerid
# 404               Arcadelt, Jacques          True        100
# 411                      Bull, John          True        100
# 412                  Farnaby, Giles          True        100
# 528                  Hinton, Arthur         False        100
# 549            Horn, Charles Edward         False        100
# 556                    Wilbye, John          True        100
# 980           Barbirolli, John, Sir         False         88
# 1030        Glover, Charles William         False        100
# 1107                   Baxter, Phil         False        100
# 1121                 Mathieu, André         False        100
# 1205                Clementi, Muzio          True        100
# 1459             Richardson, Albert         False        100
# 1778                Johnston, Bruce         False        100
# 1870            Williams, Julius P.         False         94
# 2028                Clarke, Rebecca         False        100
# 2043          Turnage, Mark-Anthony          True        100
# 2052                Pygott, Richard         False        100
# 2137                 Camilo, Michel         False        100
# 2372                 Grossman David         False        100
# 2515            Hamelin, Marc-André         False        100
# 2523          Staud, Johannes Maria         False        100
# 2668               Castri, Zosha Di         False        100
# 2706                 Jones, Jérémie         False        100
# 2718                   Ainger, Marc         False        100
# 2722                   John Nichols         False        100
# 2740               Kihlstedt, Carla         False        100
# 1369                     Scott, Tom         False        100
# 1908               Benjamin, George          True        100
#
# [28 rows x 24 columns]

# %%
get_mbz_area('61b6a12e-4751-4fe3-b40d-ecb84f29736c')
# Out:
# East Sussex
# {'id': '61b6a12e-4751-4fe3-b40d-ecb84f29736c',
#  'name': 'East Sussex',
#  'disambiguation': '',
#  'relations': [{'type-id': 'de7cc874-8b1b-3a05-8272-f3834c968fb7',
#    'begin': None,
#    'source-credit': '',
#    'attribute-values': {},
#    'area': {'disambiguation': '',
#     'id': '08328566-1f0f-4d1b-a887-12014d333aa4',
#     'sort-name': 'Fletching',
#     'name': 'Fletching'},
#    'direction': 'forward',
#    'ended': False,
#    'type': 'part of',
#    'end': None,
#    'attributes': [],
#    'target-type': 'area',
#    'target-credit': ''},
#   {'attribute-values': {},
#    'area': {'name': 'Battle',
#     'id': '0ca8bb81-1a89-459c-8c0a-9e9bd831d8d9',
#     'sort-name': 'Battle',
#     'disambiguation': ''},
#    'type-id': 'de7cc874-8b1b-3a05-8272-f3834c968fb7',
#    'source-credit': '',
#    'begin': None,
#    'target-credit': '',
#    'direction': 'forward',
#    'ended': False,
#    'type': 'part of',
#    'end': None,
#    'attributes': [],
#    'target-type': 'area'},
#   {'begin': None,
#    'source-credit': '',
#    'type-id': 'de7cc874-8b1b-3a05-8272-f3834c968fb7',
#    'area': {'disambiguation': '',
#     'name': 'East Hoathly',
#     'sort-name': 'East Hoathly',
#     'id': '0d44819e-65fd-463b-9c2e-56819eeb412b'},
#    'attribute-values': {},
#    'end': None,
#    'attributes': [],
#    'target-type': 'area',
#    'direction': 'forward',
#    'ended': False,
#    'type': 'part of',
#    'target-credit': ''},
#   {'direction': 'forward',
#    'ended': False,
#    'type': 'part of',
#    'end': None,
#    'attributes': [],
#    'target-type': 'area',
#    'target-credit': '',
#    'type-id': 'de7cc874-8b1b-3a05-8272-f3834c968fb7',
#    'source-credit': '',
#    'begin': None,
#    'attribute-values': {},
#    'area': {'id': '26812103-26b2-4cd0-8f63-62a76494a26e',
#     'sort-name': 'Hailsham',
#     'name': 'Hailsham',
#     'disambiguation': ''}},
#   {'area': {'id': '292a6892-ad77-44e5-a860-793a641c0438',
#     'sort-name': 'Heathfield',
#     'name': 'Heathfield',
#     'disambiguation': ''},
#    'attribute-values': {},
#    'begin': None,
#    'source-credit': '',
#    'type-id': 'de7cc874-8b1b-3a05-8272-f3834c968fb7',
#    'target-credit': '',
#    'target-type': 'area',
#    'attributes': [],
#    'end': None,
#    'ended': False,
#    'type': 'part of',
#    'direction': 'forward'},
#   {'attribute-values': {},
#    'area': {'name': 'Uckfield',
#     'id': '2976827c-50ed-4325-87e4-bb5032d23882',
#     'sort-name': 'Uckfield',
#     'disambiguation': ''},
#    'type-id': 'de7cc874-8b1b-3a05-8272-f3834c968fb7',
#    'source-credit': '',
#    'begin': None,
#    'target-credit': '',
#    'direction': 'forward',
#    'ended': False,
#    'type': 'part of',
#    'end': None,
#    'attributes': [],
#    'target-type': 'area'},
#   {'begin': None,
#    'source-credit': '',
#    'type-id': 'de7cc874-8b1b-3a05-8272-f3834c968fb7',
#    'area': {'disambiguation': '',
#     'sort-name': 'Bexhill-on-Sea',
#     'id': '2ba0ea6a-2f38-495a-a6b3-9241ff674480',
#     'name': 'Bexhill-on-Sea'},
#    'attribute-values': {},
#    'end': None,
#    'attributes': [],
#    'target-type': 'area',
#    'direction': 'forward',
#    'ended': False,
#    'type': 'part of',
#    'target-credit': ''},
#   {'end': None,
#    'attributes': [],
#    'target-type': 'area',
#    'direction': 'forward',
#    'ended': False,
#    'type': 'part of',
#    'target-credit': '',
#    'begin': None,
#    'source-credit': '',
#    'type-id': 'de7cc874-8b1b-3a05-8272-f3834c968fb7',
#    'area': {'name': 'Lewes',
#     'sort-name': 'Lewes',
#     'id': '7764cd51-bccd-4417-9cd4-b2fddb51f55c',
#     'disambiguation': ''},
#    'attribute-values': {}},
#   {'attribute-values': {},
#    'area': {'id': '886cf01c-ead7-47b7-b0fc-ccacb43343bd',
#     'sort-name': 'Eastbourne',
#     'name': 'Eastbourne',
#     'disambiguation': ''},
#    'type-id': 'de7cc874-8b1b-3a05-8272-f3834c968fb7',
#    'begin': None,
#    'source-credit': '',
#    'target-credit': '',
#    'direction': 'forward',
#    'ended': False,
#    'type': 'part of',
#    'end': None,
#    'attributes': [],
#    'target-type': 'area'},
#   {'attribute-values': {},
#    'area': {'name': 'Hartfield',
#     'id': '8ed0c54a-b692-479d-8bd3-d32ca8fc8a2c',
#     'sort-name': 'Hartfield',
#     'disambiguation': ''},
#    'type-id': 'de7cc874-8b1b-3a05-8272-f3834c968fb7',
#    'begin': None,
#    'source-credit': '',
#    'target-credit': '',
#    'ended': False,
#    'type': 'part of',
#    'direction': 'forward',
#    'target-type': 'area',
#    'attributes': [],
#    'end': None},
#   {'attribute-values': {},
#    'area': {'disambiguation': '',
#     'name': 'England',
#     'iso-3166-2-codes': ['GB-ENG'],
#     'sort-name': 'England',
#     'id': '9d5dd675-3cf4-4296-9e39-67865ebee758'},
#    'type-id': 'de7cc874-8b1b-3a05-8272-f3834c968fb7',
#    'begin': None,
#    'source-credit': '',
#    'target-credit': '',
#    'ended': False,
#    'type': 'part of',
#    'direction': 'backward',
#    'target-type': 'area',
#    'attributes': [],
#    'end': None},
#   {'attributes': [],
#    'target-type': 'area',
#    'end': None,
#    'ended': False,
#    'type': 'part of',
#    'direction': 'forward',
#    'target-credit': '',
#    'source-credit': '',
#    'begin': None,
#    'type-id': 'de7cc874-8b1b-3a05-8272-f3834c968fb7',
#    'area': {'id': 'c512e745-e89e-4415-b5f4-434634238311',
#     'sort-name': 'Hastings',
#     'name': 'Hastings',
#     'disambiguation': ''},
#    'attribute-values': {}},
#   {'source-credit': '',
#    'begin': None,
#    'type-id': 'de7cc874-8b1b-3a05-8272-f3834c968fb7',
#    'area': {'name': 'Rye',
#     'id': 'd2ef76c4-592a-46ad-a410-3349dac4db64',
#     'sort-name': 'Rye',
#     'disambiguation': ''},
#    'attribute-values': {},
#    'end': None,
#    'target-type': 'area',
#    'attributes': [],
#    'direction': 'forward',
#    'type': 'part of',
#    'ended': False,
#    'target-credit': ''},
#   {'area': {'name': 'Sheffield Green',
#     'id': 'de3ad06b-b10d-4fc7-9997-c26b7c30a06b',
#     'sort-name': 'Sheffield Green',
#     'disambiguation': ''},
#    'attribute-values': {},
#    'begin': None,
#    'source-credit': '',
#    'type-id': 'de7cc874-8b1b-3a05-8272-f3834c968fb7',
#    'target-credit': '',
#    'target-type': 'area',
#    'attributes': [],
#    'end': None,
#    'ended': False,
#    'type': 'part of',
#    'direction': 'forward'},
#   {'target-credit': '',
#    'ended': False,
#    'type': 'part of',
#    'direction': 'forward',
#    'attributes': [],
#    'target-type': 'area',
#    'end': None,
#    'attribute-values': {},
#    'area': {'sort-name': 'Newhaven',
#     'id': 'f0a5240c-7273-4892-b296-6ffb3d1760b6',
#     'name': 'Newhaven',
#     'disambiguation': ''},
#    'type-id': 'de7cc874-8b1b-3a05-8272-f3834c968fb7',
#    'source-credit': '',
#    'begin': None},
#   {'target-credit': '',
#    'end': None,
#    'target-type': 'area',
#    'attributes': [],
#    'direction': 'forward',
#    'ended': False,
#    'type': 'part of',
#    'area': {'disambiguation': '',
#     'sort-name': 'St Leonards-on-Sea',
#     'id': 'f497aa96-ea79-4f70-a4b3-6ac0e172a80b',
#     'name': 'St Leonards-on-Sea'},
#    'attribute-values': {},
#    'source-credit': '',
#    'begin': None,
#    'type-id': 'de7cc874-8b1b-3a05-8272-f3834c968fb7'}],
#  'type-id': 'fd3d44c5-80a1-3842-9745-2c4972d35afa',
#  'life-span': {'begin': None, 'end': None, 'ended': False},
#  'sort-name': 'East Sussex',
#  'iso-3166-2-codes': ['GB-ESX'],
#  'type': 'Subdivision'}

# %%
finaldf[final_cols].sample(5)
# Out:
#                                            mbzid            sortname gender  \
# composerid
# 1958        3fe11713-6aa2-4124-8688-08b48ea03448     Langgaard, Rued   male
# 2073        dd3c27db-7089-44cc-a5e8-6f4c435270bd        Satoh, Somei   male
# 1048        6db0064a-6b54-4ffc-9196-7cdb9d89ba3f  Mignone, Francisco   male
# 1156        01d90b8d-78bf-4369-863f-17051f3d836b        Kennan, Kent   male
# 1860        c0f43106-2abf-426a-b950-cba2bda1bb21        Amy, Gilbert   male
#
#            country                               area_id      area_name  \
# composerid
# 1958            DK  4757b525-2a60-324a-b060-578765d2c993        Denmark
# 2073            JP  2db42837-c832-3c27-b4a3-08198f75693c          Japan
# 1048            BR  f45b47f8-5796-386e-b172-6c31b009a5d8         Brazil
# 1156            US  489ce91b-6658-3307-9877-795b68554c98  United States
# 1860            FR  08310658-51eb-3801-80de-5a0739207115         France
#
#                                     beginarea_id  \
# composerid
# 1958        e0e3c82a-aea8-48d3-beda-9e587db0b969
# 2073        6b14201f-d101-4609-9632-b610aac29173
# 1048                                        None
# 1156        4dc3fa97-cf9b-43f0-bec9-fcc52d6215d5
# 1860        dc10c22b-e510-4006-8b7f-fecb4f36436e
#
#                                       endarea_id lifespan_begin lifespan_end  \
# composerid
# 1958        546a43db-1f9a-46b3-b1b4-54cb4836c3d3     1893-07-28   1952-07-10
# 2073                                        None     1947-01-19         None
# 1048                                        None     1897-09-03   1986-02-02
# 1156        58d2816b-daf9-4fc5-962c-06967f14a5e5     1913-04-18   2003-11-01
# 1860                                        None     1936-08-29         None
#
#            lifespan_ended  n_aliases  n_tags  tag_composer
# composerid
# 1958                 True          1       3          True
# 2073                 None          3       4          True
# 1048                 True          1       0         False
# 1156                 True          0       0         False
# 1860                 None          0       4          True

# %%
len(set(
    finaldf.endarea_id.unique().tolist() + 
    finaldf.beginarea_id.unique().tolist()
))
# Out:
# 1090

# %%
finaldf.iloc[0]
# Out:
# area_id              85752fda-13c4-31a3-bee5-0e5cb1f51dad
# area_name                                         Germany
# avg_score                                             100
# beginarea_id         b86b7e97-c4e2-4ec2-942b-5a6cd8eea1da
# beginarea_name                                       Bonn
# cleanname                            beethoven ludwig van
# country                                                DE
# disambig_composer                                   False
# endarea_id           afff1a94-a98b-4322-8874-3148139ab6da
# endarea_name                                         Wien
# foundname                            beethoven ludwig van
# gender                                               male
# index                                                   0
# lifespan_begin                                 1770-12-17
# lifespan_end                                   1827-03-26
# lifespan_ended                                       True
# mbzid                1f9df192-a621-4f54-8850-2c5373b7eac9
# n_aliases                                              28
# n_tags                                                 20
# pr_score                                              100
# searchname                        Beethoven,  Ludwig  van
# sortname                            Beethoven, Ludwig van
# tag_composer                                         True
# tsr_score                                             100
# Name: 0, dtype: object

# %%
finaldf.beginarea_id.sample().values
# Out:
# array(['74e50e58-5deb-4b99-93a2-decbb365c07f'], dtype=object)

# %%
import json
import requests
from time import sleep

import pandas as pd


BASE_URL = 'https://musicbrainz.org/ws/2/area/{}'
APP_HEADERS = {'User-Agent': 'NYPhil Concert Builder/0.01 (https://github.com/drewmcdonald/nyphil_concert_builder)'}


def get_mbz_area(id):
    
    params = {'fmt': 'json', 'inc': 'area-rels'}
    url = BASE_URL.format(id)
    r = requests.get(url, params=params, headers=APP_HEADERS)
    
    if r.status_code == 200:
        data = json.loads(r.content)
        print(data['sort-name'])
        if not 'iso-3166-2-codes' in data.keys():
            print('no iso code for ' + data['name'])
            rels_back = next(filter(lambda x: x['direction'] == 'backward', data['relations']))
            if rels_back is None:
                return None
            data = get_mbz_area(rels_back['area']['id'])
            if data and 'relations' in data.keys():
                data['relations'] = None
        return data
    
    if r.status_code == 503:
        print('Failed on {} ({})!'.format(id))

    print("Status code {} for {}".format(r.status_code, id))

# %%
# get_mbz_area(finaldf.beginarea_id.sample().values)
# get_mbz_area('f244bbd0-850e-4948-b288-3e10fcf39f34')
get_mbz_area(finaldf.loc[finaldf.beginarea_id.notnull()].beginarea_id.sample().values[0])
# Out:
# Neubau
# no iso code for Neubau
# Wien
# {'iso-3166-2-codes': ['AT-9'],
#  'id': 'afff1a94-a98b-4322-8874-3148139ab6da',
#  'life-span': {'ended': False, 'begin': None, 'end': None},
#  'type': 'City',
#  'sort-name': 'Wien',
#  'relations': None,
#  'name': 'Wien',
#  'disambiguation': '',
#  'type-id': '6fd8f29a-3d0a-32fc-980d-ea697b69da78'}
